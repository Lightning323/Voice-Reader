# %%
from styletts2 import tts
# Out:
# [nltk_data] Downloading package punkt to /home/sampw/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
import torch
torch.load(weights_only=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 2
#       1 import torch
# ----> 2 torch.load(weights_only=True)
#
# TypeError: load() missing 1 required positional argument: 'f'

# %%
model = tts.StyleTTS2()
# Out:
# Invalid or missing model checkpoint path. Loading default model...
# Invalid or missing config path. Loading default config...
# Invalid ASR config path. Loading default config...
# Invalid ASR model checkpoint path. Loading default model...
# ---------------------------------------------------------------------------
# UnpicklingError                           Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 model = tts.StyleTTS2()
#
# File ~/Documents/Event Horizon/Screenplay/reader/.venv/lib/python3.12/site-packages/styletts2/tts.py:81, in StyleTTS2.__init__(self, model_checkpoint_path, config_path, phoneme_converter)
#      79 self.config = None
#      80 self.model_params = None
# ---> 81 self.model = self.load_model(model_path=model_checkpoint_path, config_path=config_path)
#      83 self.sampler = DiffusionSampler(
#      84     self.model.diffusion.diffusion,
#      85     sampler=ADPM2Sampler(),
# ...

# %%
model.inference(
    "Hello! This is StyleTTS 2.",
    output_wav_file="output.wav"
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 model.inference(
#       2     "Hello! This is StyleTTS 2.",
#       3     output_wav_file="output.wav"
#       4 )
#
# NameError: name 'model' is not defined
